# %%
import pandas as pd
import numpy as np

# %%
prediction_df = pd.read_csv("submission_13.csv")
answer_df = pd.read_csv("test_answers.csv")

# %%
prediction_df.dtypes
# Out:
# id            object
# prediction    object
# dtype: object

# %%
acc = (prediction_df["prediction"] == answer_df["prediction"]).mean()
print(acc)
# Out:
# 0.33727810650887574
